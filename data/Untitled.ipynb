# %%
import pandas as pd

df = pd.read_csv('C:/Projects/RetailAnalytics/data/raw/sales.csv')

df.shape
# Out:
# (500000, 13)

# %%
df['ProfitAmount'].describe()
# Out:
# count    500000.000000
# mean        182.454790
# std         172.974212
# min           0.519000
# 25%          65.180000
# 50%         134.640000
# 75%         243.280000
# max        1791.880000
# Name: ProfitAmount, dtype: float64

# %%
df['ProfitAmount'].sum() / df['SalesAmount'].sum()
# Out:
# np.float64(0.48590464377161646)
